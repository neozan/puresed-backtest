# %%
import ccxt
import numpy as np
import pandas as pd
import datetime as dt
from dateutil import tz
import matplotlib.pyplot as plt

import json
import time
import os
import sys

# %%
src_path = 'src/'
sys.path.append(os.path.abspath(src_path))
from func_get import *
from func_signal import *
from func_backtest import *

# %%
start_ts = time.time()

# %%
interval_dict = {
    '1m': 1,
    '5m': 5,x 
    '15m': 15,
    '30m': 30,
    '1h': 60,
    '2h': 120,
    '4h': 240,
    '1d': 1440
}

# %%
with open('../../_keys/ftx/ftx_read_keys.json') as keys_file:
    keys_dict = json.load(keys_file)
    
exchange = ccxt.ftx({'apiKey': keys_dict['apiKey'],
                     'secret': keys_dict['secret'],
                     'enableRateLimit': True})

# %% [markdown]
# ### Config

# %%
project_name = 'messi_revert'

# %%
start_date = dt.datetime(2021, 1, 1)
start_hour = 1
end_date = dt.datetime.today() - dt.timedelta(days=1)
reinvest_profit_flag = True

# %%
config_params = {
    'safety_ohlcv_range': 1000,
    'action_timeframe': '2h',
    'base': {
        'symbol': ['ETH-PERP'],
        'open': {
            '2h': {
                'tma': {
                    'check': [check_signal_price, check_signal_side_change],
                    'look_back': 1,
                    'windows': 50,
                    'revert': True
                }
            }
        },
        'close': {
            '2h': {
                'tma': {
                    'check': [check_signal_price],
                    'look_back': 1,
                    'windows': 50,
                    'revert': True
                }
            }
        }
    },
    'lead': {
        'symbol': [],
        'open': {
        },
        'close': {
        }
    },
    'tp': {
        'price_percent': None,
        'signal': None,
    },
    'sl': {
        'price_percent': None,
        'signal': None
    },
    'action_percent': 1,
    'leverage': 1,
    'taker_fee': 0.07
}

# %% [markdown]
# ### Get data

# %%
ohlcv_df_dict = get_data(exchange, start_date, end_date, start_hour, interval_dict, config_params)
# Out:
# base: timeframe 1/1 symbol 1/1 date 1/587
# base: timeframe 1/1 symbol 1/1 date 2/587
# base: timeframe 1/1 symbol 1/1 date 3/587
# base: timeframe 1/1 symbol 1/1 date 4/587
# base: timeframe 1/1 symbol 1/1 date 5/587
# base: timeframe 1/1 symbol 1/1 date 6/587
# base: timeframe 1/1 symbol 1/1 date 7/587
# base: timeframe 1/1 symbol 1/1 date 8/587
# base: timeframe 1/1 symbol 1/1 date 9/587
# base: timeframe 1/1 symbol 1/1 date 10/587
# base: timeframe 1/1 symbol 1/1 date 11/587
# base: timeframe 1/1 symbol 1/1 date 12/587
# base: timeframe 1/1 symbol 1/1 date 13/587
# base: timeframe 1/1 symbol 1/1 date 14/587
# base: timeframe 1/1 symbol 1/1 date 15/587
# base: timeframe 1/1 symbol 1/1 date 16/587
# base: timeframe 1/1 symbol 1/1 date 17/587
# base: timeframe 1/1 symbol 1/1 date 18/587
# base: timeframe 1/1 symbol 1/1 date 19/587
# base: timeframe 1/1 symbol 1/1 date 20/587
# base: timeframe 1/1 symbol 1/1 date 21/587
# base: timeframe 1/1 symbol 1/1 date 22/587
# base: timeframe 1/1 symbol 1/1 date 23/587
# base: timeframe 1/1 symbol 1/1 date 24/587
# base: timeframe 1/1 symbol 1/1 date 25/587
# base: timeframe 1/1 symbol 1/1 date 26/587
# base: timeframe 1/1 symbol 1/1 date 27/587
# base: timeframe 1/1 symbol 1/1 date 28/587
# base: timeframe 1/1 symbol 1/1 date 29/587
# base: timeframe 1/1 symbol 1/1 date 30/587
# base: timeframe 1/1 symbol 1/1 date 31/587
# base: timeframe 1/1 symbol 1/1 date 32/587
# base: timeframe 1/1 symbol 1/1 date 33/587
# base: timeframe 1/1 symbol 1/1 date 34/587
# base: timeframe 1/1 symbol 1/1 date 35/587
# base: timeframe 1/1 symbol 1/1 date 36/587
# base: timeframe 1/1 symbol 1/1 date 37/587
# base: timeframe 1/1 symbol 1/1 date 38/587
# base: timeframe 1/1 symbol 1/1 date 39/587
# base: timeframe 1/1 symbol 1/1 date 40/587
# base: timeframe 1/1 symbol 1/1 date 41/587
# base: timeframe 1/1 symbol 1/1 date 42/587
# base: timeframe 1/1 symbol 1/1 date 43/587
# base: timeframe 1/1 symbol 1/1 date 44/587
# base: timeframe 1/1 symbol 1/1 date 45/587
# base: timeframe 1/1 symbol 1/1 date 46/587
# base: timeframe 1/1 symbol 1/1 date 47/587
# base: timeframe 1/1 symbol 1/1 date 48/587
# base: timeframe 1/1 symbol 1/1 date 49/587
# base: timeframe 1/1 symbol 1/1 date 50/587
# base: timeframe 1/1 symbol 1/1 date 51/587
# base: timeframe 1/1 symbol 1/1 date 52/587
# base: timeframe 1/1 symbol 1/1 date 53/587
# base: timeframe 1/1 symbol 1/1 date 54/587
# base: timeframe 1/1 symbol 1/1 date 55/587
# base: timeframe 1/1 symbol 1/1 date 56/587
# base: timeframe 1/1 symbol 1/1 date 57/587
# base: timeframe 1/1 symbol 1/1 date 58/587
# base: timeframe 1/1 symbol 1/1 date 59/587
# base: timeframe 1/1 symbol 1/1 date 60/587
# base: timeframe 1/1 symbol 1/1 date 61/587
# base: timeframe 1/1 symbol 1/1 date 62/587
# base: timeframe 1/1 symbol 1/1 date 63/587
# base: timeframe 1/1 symbol 1/1 date 64/587
# base: timeframe 1/1 symbol 1/1 date 65/587
# base: timeframe 1/1 symbol 1/1 date 66/587
# base: timeframe 1/1 symbol 1/1 date 67/587
# base: timeframe 1/1 symbol 1/1 date 68/587
# base: timeframe 1/1 symbol 1/1 date 69/587
# base: timeframe 1/1 symbol 1/1 date 70/587
# base: timeframe 1/1 symbol 1/1 date 71/587
# base: timeframe 1/1 symbol 1/1 date 72/587
# base: timeframe 1/1 symbol 1/1 date 73/587
# base: timeframe 1/1 symbol 1/1 date 74/587
# base: timeframe 1/1 symbol 1/1 date 75/587
# base: timeframe 1/1 symbol 1/1 date 76/587
# base: timeframe 1/1 symbol 1/1 date 77/587
# base: timeframe 1/1 symbol 1/1 date 78/587
# base: timeframe 1/1 symbol 1/1 date 79/587
# base: timeframe 1/1 symbol 1/1 date 80/587
# base: timeframe 1/1 symbol 1/1 date 81/587
# base: timeframe 1/1 symbol 1/1 date 82/587
# base: timeframe 1/1 symbol 1/1 date 83/587
# base: timeframe 1/1 symbol 1/1 date 84/587
# base: timeframe 1/1 symbol 1/1 date 85/587
# base: timeframe 1/1 symbol 1/1 date 86/587
# base: timeframe 1/1 symbol 1/1 date 87/587
# base: timeframe 1/1 symbol 1/1 date 88/587
# base: timeframe 1/1 symbol 1/1 date 89/587
# base: timeframe 1/1 symbol 1/1 date 90/587
# base: timeframe 1/1 symbol 1/1 date 91/587
# base: timeframe 1/1 symbol 1/1 date 92/587
# base: timeframe 1/1 symbol 1/1 date 93/587
# base: timeframe 1/1 symbol 1/1 date 94/587
# base: timeframe 1/1 symbol 1/1 date 95/587
# base: timeframe 1/1 symbol 1/1 date 96/587
# base: timeframe 1/1 symbol 1/1 date 97/587
# base: timeframe 1/1 symbol 1/1 date 98/587
# base: timeframe 1/1 symbol 1/1 date 99/587
# base: timeframe 1/1 symbol 1/1 date 100/587
# base: timeframe 1/1 symbol 1/1 date 101/587
# base: timeframe 1/1 symbol 1/1 date 102/587
# base: timeframe 1/1 symbol 1/1 date 103/587
# base: timeframe 1/1 symbol 1/1 date 104/587
# base: timeframe 1/1 symbol 1/1 date 105/587
# base: timeframe 1/1 symbol 1/1 date 106/587
# base: timeframe 1/1 symbol 1/1 date 107/587
# base: timeframe 1/1 symbol 1/1 date 108/587
# base: timeframe 1/1 symbol 1/1 date 109/587
# base: timeframe 1/1 symbol 1/1 date 110/587
# base: timeframe 1/1 symbol 1/1 date 111/587
# base: timeframe 1/1 symbol 1/1 date 112/587
# base: timeframe 1/1 symbol 1/1 date 113/587
# base: timeframe 1/1 symbol 1/1 date 114/587
# base: timeframe 1/1 symbol 1/1 date 115/587
# base: timeframe 1/1 symbol 1/1 date 116/587
# base: timeframe 1/1 symbol 1/1 date 117/587
# base: timeframe 1/1 symbol 1/1 date 118/587
# base: timeframe 1/1 symbol 1/1 date 119/587
# base: timeframe 1/1 symbol 1/1 date 120/587
# base: timeframe 1/1 symbol 1/1 date 121/587
# base: timeframe 1/1 symbol 1/1 date 122/587
# base: timeframe 1/1 symbol 1/1 date 123/587
# base: timeframe 1/1 symbol 1/1 date 124/587
# base: timeframe 1/1 symbol 1/1 date 125/587
# base: timeframe 1/1 symbol 1/1 date 126/587
# base: timeframe 1/1 symbol 1/1 date 127/587
# base: timeframe 1/1 symbol 1/1 date 128/587
# base: timeframe 1/1 symbol 1/1 date 129/587
# base: timeframe 1/1 symbol 1/1 date 130/587
# base: timeframe 1/1 symbol 1/1 date 131/587
# base: timeframe 1/1 symbol 1/1 date 132/587
# base: timeframe 1/1 symbol 1/1 date 133/587
# base: timeframe 1/1 symbol 1/1 date 134/587
# base: timeframe 1/1 symbol 1/1 date 135/587
# base: timeframe 1/1 symbol 1/1 date 136/587
# base: timeframe 1/1 symbol 1/1 date 137/587
# base: timeframe 1/1 symbol 1/1 date 138/587
# base: timeframe 1/1 symbol 1/1 date 139/587
# base: timeframe 1/1 symbol 1/1 date 140/587
# base: timeframe 1/1 symbol 1/1 date 141/587
# base: timeframe 1/1 symbol 1/1 date 142/587
# base: timeframe 1/1 symbol 1/1 date 143/587
# base: timeframe 1/1 symbol 1/1 date 144/587
# base: timeframe 1/1 symbol 1/1 date 145/587
# base: timeframe 1/1 symbol 1/1 date 146/587
# base: timeframe 1/1 symbol 1/1 date 147/587
# base: timeframe 1/1 symbol 1/1 date 148/587
# base: timeframe 1/1 symbol 1/1 date 149/587
# base: timeframe 1/1 symbol 1/1 date 150/587
# base: timeframe 1/1 symbol 1/1 date 151/587
# base: timeframe 1/1 symbol 1/1 date 152/587
# base: timeframe 1/1 symbol 1/1 date 153/587
# base: timeframe 1/1 symbol 1/1 date 154/587
# base: timeframe 1/1 symbol 1/1 date 155/587
# base: timeframe 1/1 symbol 1/1 date 156/587
# base: timeframe 1/1 symbol 1/1 date 157/587
# base: timeframe 1/1 symbol 1/1 date 158/587
# base: timeframe 1/1 symbol 1/1 date 159/587
# base: timeframe 1/1 symbol 1/1 date 160/587
# base: timeframe 1/1 symbol 1/1 date 161/587
# base: timeframe 1/1 symbol 1/1 date 162/587
# base: timeframe 1/1 symbol 1/1 date 163/587
# base: timeframe 1/1 symbol 1/1 date 164/587
# base: timeframe 1/1 symbol 1/1 date 165/587
# base: timeframe 1/1 symbol 1/1 date 166/587
# base: timeframe 1/1 symbol 1/1 date 167/587
# base: timeframe 1/1 symbol 1/1 date 168/587
# base: timeframe 1/1 symbol 1/1 date 169/587
# base: timeframe 1/1 symbol 1/1 date 170/587
# base: timeframe 1/1 symbol 1/1 date 171/587
# base: timeframe 1/1 symbol 1/1 date 172/587
# base: timeframe 1/1 symbol 1/1 date 173/587
# base: timeframe 1/1 symbol 1/1 date 174/587
# base: timeframe 1/1 symbol 1/1 date 175/587
# base: timeframe 1/1 symbol 1/1 date 176/587
# base: timeframe 1/1 symbol 1/1 date 177/587
# base: timeframe 1/1 symbol 1/1 date 178/587
# base: timeframe 1/1 symbol 1/1 date 179/587
# base: timeframe 1/1 symbol 1/1 date 180/587
# base: timeframe 1/1 symbol 1/1 date 181/587
# base: timeframe 1/1 symbol 1/1 date 182/587
# base: timeframe 1/1 symbol 1/1 date 183/587
# base: timeframe 1/1 symbol 1/1 date 184/587
# base: timeframe 1/1 symbol 1/1 date 185/587
# base: timeframe 1/1 symbol 1/1 date 186/587
# base: timeframe 1/1 symbol 1/1 date 187/587
# base: timeframe 1/1 symbol 1/1 date 188/587
# base: timeframe 1/1 symbol 1/1 date 189/587
# base: timeframe 1/1 symbol 1/1 date 190/587
# base: timeframe 1/1 symbol 1/1 date 191/587
# base: timeframe 1/1 symbol 1/1 date 192/587
# base: timeframe 1/1 symbol 1/1 date 193/587
# base: timeframe 1/1 symbol 1/1 date 194/587
# base: timeframe 1/1 symbol 1/1 date 195/587
# base: timeframe 1/1 symbol 1/1 date 196/587
# base: timeframe 1/1 symbol 1/1 date 197/587
# base: timeframe 1/1 symbol 1/1 date 198/587
# base: timeframe 1/1 symbol 1/1 date 199/587
# base: timeframe 1/1 symbol 1/1 date 200/587
# base: timeframe 1/1 symbol 1/1 date 201/587
# base: timeframe 1/1 symbol 1/1 date 202/587
# base: timeframe 1/1 symbol 1/1 date 203/587
# base: timeframe 1/1 symbol 1/1 date 204/587
# base: timeframe 1/1 symbol 1/1 date 205/587
# base: timeframe 1/1 symbol 1/1 date 206/587
# base: timeframe 1/1 symbol 1/1 date 207/587
# base: timeframe 1/1 symbol 1/1 date 208/587
# base: timeframe 1/1 symbol 1/1 date 209/587
# base: timeframe 1/1 symbol 1/1 date 210/587
# base: timeframe 1/1 symbol 1/1 date 211/587
# base: timeframe 1/1 symbol 1/1 date 212/587
# base: timeframe 1/1 symbol 1/1 date 213/587
# base: timeframe 1/1 symbol 1/1 date 214/587
# base: timeframe 1/1 symbol 1/1 date 215/587
# base: timeframe 1/1 symbol 1/1 date 216/587
# base: timeframe 1/1 symbol 1/1 date 217/587
# base: timeframe 1/1 symbol 1/1 date 218/587
# base: timeframe 1/1 symbol 1/1 date 219/587
# base: timeframe 1/1 symbol 1/1 date 220/587
# base: timeframe 1/1 symbol 1/1 date 221/587
# base: timeframe 1/1 symbol 1/1 date 222/587
# base: timeframe 1/1 symbol 1/1 date 223/587
# base: timeframe 1/1 symbol 1/1 date 224/587
# base: timeframe 1/1 symbol 1/1 date 225/587
# base: timeframe 1/1 symbol 1/1 date 226/587
# base: timeframe 1/1 symbol 1/1 date 227/587
# base: timeframe 1/1 symbol 1/1 date 228/587
# base: timeframe 1/1 symbol 1/1 date 229/587
# base: timeframe 1/1 symbol 1/1 date 230/587
# base: timeframe 1/1 symbol 1/1 date 231/587
# base: timeframe 1/1 symbol 1/1 date 232/587
# base: timeframe 1/1 symbol 1/1 date 233/587
# base: timeframe 1/1 symbol 1/1 date 234/587
# base: timeframe 1/1 symbol 1/1 date 235/587
# base: timeframe 1/1 symbol 1/1 date 236/587
# base: timeframe 1/1 symbol 1/1 date 237/587
# base: timeframe 1/1 symbol 1/1 date 238/587
# base: timeframe 1/1 symbol 1/1 date 239/587
# base: timeframe 1/1 symbol 1/1 date 240/587
# base: timeframe 1/1 symbol 1/1 date 241/587
# base: timeframe 1/1 symbol 1/1 date 242/587
# base: timeframe 1/1 symbol 1/1 date 243/587
# base: timeframe 1/1 symbol 1/1 date 244/587
# base: timeframe 1/1 symbol 1/1 date 245/587
# base: timeframe 1/1 symbol 1/1 date 246/587
# base: timeframe 1/1 symbol 1/1 date 247/587
# base: timeframe 1/1 symbol 1/1 date 248/587
# base: timeframe 1/1 symbol 1/1 date 249/587
# base: timeframe 1/1 symbol 1/1 date 250/587
# base: timeframe 1/1 symbol 1/1 date 251/587
# base: timeframe 1/1 symbol 1/1 date 252/587
# base: timeframe 1/1 symbol 1/1 date 253/587
# base: timeframe 1/1 symbol 1/1 date 254/587
# base: timeframe 1/1 symbol 1/1 date 255/587
# base: timeframe 1/1 symbol 1/1 date 256/587
# base: timeframe 1/1 symbol 1/1 date 257/587
# base: timeframe 1/1 symbol 1/1 date 258/587
# base: timeframe 1/1 symbol 1/1 date 259/587
# base: timeframe 1/1 symbol 1/1 date 260/587
# base: timeframe 1/1 symbol 1/1 date 261/587
# base: timeframe 1/1 symbol 1/1 date 262/587
# base: timeframe 1/1 symbol 1/1 date 263/587
# base: timeframe 1/1 symbol 1/1 date 264/587
# base: timeframe 1/1 symbol 1/1 date 265/587
# base: timeframe 1/1 symbol 1/1 date 266/587
# base: timeframe 1/1 symbol 1/1 date 267/587
# base: timeframe 1/1 symbol 1/1 date 268/587
# base: timeframe 1/1 symbol 1/1 date 269/587
# base: timeframe 1/1 symbol 1/1 date 270/587
# base: timeframe 1/1 symbol 1/1 date 271/587
# base: timeframe 1/1 symbol 1/1 date 272/587
# base: timeframe 1/1 symbol 1/1 date 273/587
# base: timeframe 1/1 symbol 1/1 date 274/587
# base: timeframe 1/1 symbol 1/1 date 275/587
# base: timeframe 1/1 symbol 1/1 date 276/587
# base: timeframe 1/1 symbol 1/1 date 277/587
# base: timeframe 1/1 symbol 1/1 date 278/587
# base: timeframe 1/1 symbol 1/1 date 279/587
# base: timeframe 1/1 symbol 1/1 date 280/587
# base: timeframe 1/1 symbol 1/1 date 281/587
# base: timeframe 1/1 symbol 1/1 date 282/587
# base: timeframe 1/1 symbol 1/1 date 283/587
# base: timeframe 1/1 symbol 1/1 date 284/587
# base: timeframe 1/1 symbol 1/1 date 285/587
# base: timeframe 1/1 symbol 1/1 date 286/587
# base: timeframe 1/1 symbol 1/1 date 287/587
# base: timeframe 1/1 symbol 1/1 date 288/587
# base: timeframe 1/1 symbol 1/1 date 289/587
# base: timeframe 1/1 symbol 1/1 date 290/587
# base: timeframe 1/1 symbol 1/1 date 291/587
# base: timeframe 1/1 symbol 1/1 date 292/587
# base: timeframe 1/1 symbol 1/1 date 293/587
# base: timeframe 1/1 symbol 1/1 date 294/587
# base: timeframe 1/1 symbol 1/1 date 295/587
# base: timeframe 1/1 symbol 1/1 date 296/587
# base: timeframe 1/1 symbol 1/1 date 297/587
# base: timeframe 1/1 symbol 1/1 date 298/587
# base: timeframe 1/1 symbol 1/1 date 299/587
# base: timeframe 1/1 symbol 1/1 date 300/587
# base: timeframe 1/1 symbol 1/1 date 301/587
# base: timeframe 1/1 symbol 1/1 date 302/587
# base: timeframe 1/1 symbol 1/1 date 303/587
# base: timeframe 1/1 symbol 1/1 date 304/587
# base: timeframe 1/1 symbol 1/1 date 305/587
# base: timeframe 1/1 symbol 1/1 date 306/587
# base: timeframe 1/1 symbol 1/1 date 307/587
# base: timeframe 1/1 symbol 1/1 date 308/587
# base: timeframe 1/1 symbol 1/1 date 309/587
# base: timeframe 1/1 symbol 1/1 date 310/587
# base: timeframe 1/1 symbol 1/1 date 311/587
# base: timeframe 1/1 symbol 1/1 date 312/587
# base: timeframe 1/1 symbol 1/1 date 313/587
# base: timeframe 1/1 symbol 1/1 date 314/587
# base: timeframe 1/1 symbol 1/1 date 315/587
# base: timeframe 1/1 symbol 1/1 date 316/587
# base: timeframe 1/1 symbol 1/1 date 317/587
# base: timeframe 1/1 symbol 1/1 date 318/587
# base: timeframe 1/1 symbol 1/1 date 319/587
# base: timeframe 1/1 symbol 1/1 date 320/587
# base: timeframe 1/1 symbol 1/1 date 321/587
# base: timeframe 1/1 symbol 1/1 date 322/587
# base: timeframe 1/1 symbol 1/1 date 323/587
# base: timeframe 1/1 symbol 1/1 date 324/587
# base: timeframe 1/1 symbol 1/1 date 325/587
# base: timeframe 1/1 symbol 1/1 date 326/587
# base: timeframe 1/1 symbol 1/1 date 327/587
# base: timeframe 1/1 symbol 1/1 date 328/587
# base: timeframe 1/1 symbol 1/1 date 329/587
# base: timeframe 1/1 symbol 1/1 date 330/587
# base: timeframe 1/1 symbol 1/1 date 331/587
# base: timeframe 1/1 symbol 1/1 date 332/587
# base: timeframe 1/1 symbol 1/1 date 333/587
# base: timeframe 1/1 symbol 1/1 date 334/587
# base: timeframe 1/1 symbol 1/1 date 335/587
# base: timeframe 1/1 symbol 1/1 date 336/587
# base: timeframe 1/1 symbol 1/1 date 337/587
# base: timeframe 1/1 symbol 1/1 date 338/587
# base: timeframe 1/1 symbol 1/1 date 339/587
# base: timeframe 1/1 symbol 1/1 date 340/587
# base: timeframe 1/1 symbol 1/1 date 341/587
# base: timeframe 1/1 symbol 1/1 date 342/587
# base: timeframe 1/1 symbol 1/1 date 343/587
# base: timeframe 1/1 symbol 1/1 date 344/587
# base: timeframe 1/1 symbol 1/1 date 345/587
# base: timeframe 1/1 symbol 1/1 date 346/587
# base: timeframe 1/1 symbol 1/1 date 347/587
# base: timeframe 1/1 symbol 1/1 date 348/587
# base: timeframe 1/1 symbol 1/1 date 349/587
# base: timeframe 1/1 symbol 1/1 date 350/587
# base: timeframe 1/1 symbol 1/1 date 351/587
# base: timeframe 1/1 symbol 1/1 date 352/587
# base: timeframe 1/1 symbol 1/1 date 353/587
# base: timeframe 1/1 symbol 1/1 date 354/587
# base: timeframe 1/1 symbol 1/1 date 355/587
# base: timeframe 1/1 symbol 1/1 date 356/587
# base: timeframe 1/1 symbol 1/1 date 357/587
# base: timeframe 1/1 symbol 1/1 date 358/587
# base: timeframe 1/1 symbol 1/1 date 359/587
# base: timeframe 1/1 symbol 1/1 date 360/587
# base: timeframe 1/1 symbol 1/1 date 361/587
# base: timeframe 1/1 symbol 1/1 date 362/587
# base: timeframe 1/1 symbol 1/1 date 363/587
# base: timeframe 1/1 symbol 1/1 date 364/587
# base: timeframe 1/1 symbol 1/1 date 365/587
# base: timeframe 1/1 symbol 1/1 date 366/587
# base: timeframe 1/1 symbol 1/1 date 367/587
# base: timeframe 1/1 symbol 1/1 date 368/587
# base: timeframe 1/1 symbol 1/1 date 369/587
# base: timeframe 1/1 symbol 1/1 date 370/587
# base: timeframe 1/1 symbol 1/1 date 371/587
# base: timeframe 1/1 symbol 1/1 date 372/587
# base: timeframe 1/1 symbol 1/1 date 373/587
# base: timeframe 1/1 symbol 1/1 date 374/587
# base: timeframe 1/1 symbol 1/1 date 375/587
# base: timeframe 1/1 symbol 1/1 date 376/587
# base: timeframe 1/1 symbol 1/1 date 377/587
# base: timeframe 1/1 symbol 1/1 date 378/587
# base: timeframe 1/1 symbol 1/1 date 379/587
# base: timeframe 1/1 symbol 1/1 date 380/587
# base: timeframe 1/1 symbol 1/1 date 381/587
# base: timeframe 1/1 symbol 1/1 date 382/587
# base: timeframe 1/1 symbol 1/1 date 383/587
# base: timeframe 1/1 symbol 1/1 date 384/587
# base: timeframe 1/1 symbol 1/1 date 385/587
# base: timeframe 1/1 symbol 1/1 date 386/587
# base: timeframe 1/1 symbol 1/1 date 387/587
# base: timeframe 1/1 symbol 1/1 date 388/587
# base: timeframe 1/1 symbol 1/1 date 389/587
# base: timeframe 1/1 symbol 1/1 date 390/587
# base: timeframe 1/1 symbol 1/1 date 391/587
# base: timeframe 1/1 symbol 1/1 date 392/587
# base: timeframe 1/1 symbol 1/1 date 393/587
# base: timeframe 1/1 symbol 1/1 date 394/587
# base: timeframe 1/1 symbol 1/1 date 395/587
# base: timeframe 1/1 symbol 1/1 date 396/587
# base: timeframe 1/1 symbol 1/1 date 397/587
# base: timeframe 1/1 symbol 1/1 date 398/587
# base: timeframe 1/1 symbol 1/1 date 399/587
# base: timeframe 1/1 symbol 1/1 date 400/587
# base: timeframe 1/1 symbol 1/1 date 401/587
# base: timeframe 1/1 symbol 1/1 date 402/587
# base: timeframe 1/1 symbol 1/1 date 403/587
# base: timeframe 1/1 symbol 1/1 date 404/587
# base: timeframe 1/1 symbol 1/1 date 405/587
# base: timeframe 1/1 symbol 1/1 date 406/587
# base: timeframe 1/1 symbol 1/1 date 407/587
# base: timeframe 1/1 symbol 1/1 date 408/587
# base: timeframe 1/1 symbol 1/1 date 409/587
# base: timeframe 1/1 symbol 1/1 date 410/587
# base: timeframe 1/1 symbol 1/1 date 411/587
# base: timeframe 1/1 symbol 1/1 date 412/587
# base: timeframe 1/1 symbol 1/1 date 413/587
# base: timeframe 1/1 symbol 1/1 date 414/587
# base: timeframe 1/1 symbol 1/1 date 415/587
# base: timeframe 1/1 symbol 1/1 date 416/587
# base: timeframe 1/1 symbol 1/1 date 417/587
# base: timeframe 1/1 symbol 1/1 date 418/587
# base: timeframe 1/1 symbol 1/1 date 419/587
# base: timeframe 1/1 symbol 1/1 date 420/587
# base: timeframe 1/1 symbol 1/1 date 421/587
# base: timeframe 1/1 symbol 1/1 date 422/587
# base: timeframe 1/1 symbol 1/1 date 423/587
# base: timeframe 1/1 symbol 1/1 date 424/587
# base: timeframe 1/1 symbol 1/1 date 425/587
# base: timeframe 1/1 symbol 1/1 date 426/587
# base: timeframe 1/1 symbol 1/1 date 427/587
# base: timeframe 1/1 symbol 1/1 date 428/587
# base: timeframe 1/1 symbol 1/1 date 429/587
# base: timeframe 1/1 symbol 1/1 date 430/587
# base: timeframe 1/1 symbol 1/1 date 431/587
# base: timeframe 1/1 symbol 1/1 date 432/587
# base: timeframe 1/1 symbol 1/1 date 433/587
# base: timeframe 1/1 symbol 1/1 date 434/587
# base: timeframe 1/1 symbol 1/1 date 435/587
# base: timeframe 1/1 symbol 1/1 date 436/587
# base: timeframe 1/1 symbol 1/1 date 437/587
# base: timeframe 1/1 symbol 1/1 date 438/587
# base: timeframe 1/1 symbol 1/1 date 439/587
# base: timeframe 1/1 symbol 1/1 date 440/587
# base: timeframe 1/1 symbol 1/1 date 441/587
# base: timeframe 1/1 symbol 1/1 date 442/587
# base: timeframe 1/1 symbol 1/1 date 443/587
# base: timeframe 1/1 symbol 1/1 date 444/587
# base: timeframe 1/1 symbol 1/1 date 445/587
# base: timeframe 1/1 symbol 1/1 date 446/587
# base: timeframe 1/1 symbol 1/1 date 447/587
# base: timeframe 1/1 symbol 1/1 date 448/587
# base: timeframe 1/1 symbol 1/1 date 449/587
# base: timeframe 1/1 symbol 1/1 date 450/587
# base: timeframe 1/1 symbol 1/1 date 451/587
# base: timeframe 1/1 symbol 1/1 date 452/587
# base: timeframe 1/1 symbol 1/1 date 453/587
# base: timeframe 1/1 symbol 1/1 date 454/587
# base: timeframe 1/1 symbol 1/1 date 455/587
# base: timeframe 1/1 symbol 1/1 date 456/587
# base: timeframe 1/1 symbol 1/1 date 457/587
# base: timeframe 1/1 symbol 1/1 date 458/587
# base: timeframe 1/1 symbol 1/1 date 459/587
# base: timeframe 1/1 symbol 1/1 date 460/587
# base: timeframe 1/1 symbol 1/1 date 461/587
# base: timeframe 1/1 symbol 1/1 date 462/587
# base: timeframe 1/1 symbol 1/1 date 463/587
# base: timeframe 1/1 symbol 1/1 date 464/587
# base: timeframe 1/1 symbol 1/1 date 465/587
# base: timeframe 1/1 symbol 1/1 date 466/587
# base: timeframe 1/1 symbol 1/1 date 467/587
# base: timeframe 1/1 symbol 1/1 date 468/587
# base: timeframe 1/1 symbol 1/1 date 469/587
# base: timeframe 1/1 symbol 1/1 date 470/587
# base: timeframe 1/1 symbol 1/1 date 471/587
# base: timeframe 1/1 symbol 1/1 date 472/587
# base: timeframe 1/1 symbol 1/1 date 473/587
# base: timeframe 1/1 symbol 1/1 date 474/587
# base: timeframe 1/1 symbol 1/1 date 475/587
# base: timeframe 1/1 symbol 1/1 date 476/587
# base: timeframe 1/1 symbol 1/1 date 477/587
# base: timeframe 1/1 symbol 1/1 date 478/587
# base: timeframe 1/1 symbol 1/1 date 479/587
# base: timeframe 1/1 symbol 1/1 date 480/587
# base: timeframe 1/1 symbol 1/1 date 481/587
# base: timeframe 1/1 symbol 1/1 date 482/587
# base: timeframe 1/1 symbol 1/1 date 483/587
# base: timeframe 1/1 symbol 1/1 date 484/587
# base: timeframe 1/1 symbol 1/1 date 485/587
# base: timeframe 1/1 symbol 1/1 date 486/587
# base: timeframe 1/1 symbol 1/1 date 487/587
# base: timeframe 1/1 symbol 1/1 date 488/587
# base: timeframe 1/1 symbol 1/1 date 489/587
# base: timeframe 1/1 symbol 1/1 date 490/587
# base: timeframe 1/1 symbol 1/1 date 491/587
# base: timeframe 1/1 symbol 1/1 date 492/587
# base: timeframe 1/1 symbol 1/1 date 493/587
# base: timeframe 1/1 symbol 1/1 date 494/587
# base: timeframe 1/1 symbol 1/1 date 495/587
# base: timeframe 1/1 symbol 1/1 date 496/587
# base: timeframe 1/1 symbol 1/1 date 497/587
# base: timeframe 1/1 symbol 1/1 date 498/587
# base: timeframe 1/1 symbol 1/1 date 499/587
# base: timeframe 1/1 symbol 1/1 date 500/587
# base: timeframe 1/1 symbol 1/1 date 501/587
# base: timeframe 1/1 symbol 1/1 date 502/587
# base: timeframe 1/1 symbol 1/1 date 503/587
# base: timeframe 1/1 symbol 1/1 date 504/587
# base: timeframe 1/1 symbol 1/1 date 505/587
# base: timeframe 1/1 symbol 1/1 date 506/587
# base: timeframe 1/1 symbol 1/1 date 507/587
# base: timeframe 1/1 symbol 1/1 date 508/587
# base: timeframe 1/1 symbol 1/1 date 509/587
# base: timeframe 1/1 symbol 1/1 date 510/587
# base: timeframe 1/1 symbol 1/1 date 511/587
# base: timeframe 1/1 symbol 1/1 date 512/587
# base: timeframe 1/1 symbol 1/1 date 513/587
# base: timeframe 1/1 symbol 1/1 date 514/587
# base: timeframe 1/1 symbol 1/1 date 515/587
# base: timeframe 1/1 symbol 1/1 date 516/587
# base: timeframe 1/1 symbol 1/1 date 517/587
# base: timeframe 1/1 symbol 1/1 date 518/587
# base: timeframe 1/1 symbol 1/1 date 519/587
# base: timeframe 1/1 symbol 1/1 date 520/587
# base: timeframe 1/1 symbol 1/1 date 521/587
# base: timeframe 1/1 symbol 1/1 date 522/587
# base: timeframe 1/1 symbol 1/1 date 523/587
# base: timeframe 1/1 symbol 1/1 date 524/587
# base: timeframe 1/1 symbol 1/1 date 525/587
# base: timeframe 1/1 symbol 1/1 date 526/587
# base: timeframe 1/1 symbol 1/1 date 527/587
# base: timeframe 1/1 symbol 1/1 date 528/587
# base: timeframe 1/1 symbol 1/1 date 529/587
# base: timeframe 1/1 symbol 1/1 date 530/587
# base: timeframe 1/1 symbol 1/1 date 531/587
# base: timeframe 1/1 symbol 1/1 date 532/587
# base: timeframe 1/1 symbol 1/1 date 533/587
# base: timeframe 1/1 symbol 1/1 date 534/587
# base: timeframe 1/1 symbol 1/1 date 535/587
# base: timeframe 1/1 symbol 1/1 date 536/587
# base: timeframe 1/1 symbol 1/1 date 537/587
# base: timeframe 1/1 symbol 1/1 date 538/587
# base: timeframe 1/1 symbol 1/1 date 539/587
# base: timeframe 1/1 symbol 1/1 date 540/587
# base: timeframe 1/1 symbol 1/1 date 541/587
# base: timeframe 1/1 symbol 1/1 date 542/587
# base: timeframe 1/1 symbol 1/1 date 543/587
# base: timeframe 1/1 symbol 1/1 date 544/587
# base: timeframe 1/1 symbol 1/1 date 545/587
# base: timeframe 1/1 symbol 1/1 date 546/587
# base: timeframe 1/1 symbol 1/1 date 547/587
# base: timeframe 1/1 symbol 1/1 date 548/587
# base: timeframe 1/1 symbol 1/1 date 549/587
# base: timeframe 1/1 symbol 1/1 date 550/587
# base: timeframe 1/1 symbol 1/1 date 551/587
# base: timeframe 1/1 symbol 1/1 date 552/587
# base: timeframe 1/1 symbol 1/1 date 553/587
# base: timeframe 1/1 symbol 1/1 date 554/587
# base: timeframe 1/1 symbol 1/1 date 555/587
# base: timeframe 1/1 symbol 1/1 date 556/587
# base: timeframe 1/1 symbol 1/1 date 557/587
# base: timeframe 1/1 symbol 1/1 date 558/587
# base: timeframe 1/1 symbol 1/1 date 559/587
# base: timeframe 1/1 symbol 1/1 date 560/587
# base: timeframe 1/1 symbol 1/1 date 561/587
# base: timeframe 1/1 symbol 1/1 date 562/587
# base: timeframe 1/1 symbol 1/1 date 563/587
# base: timeframe 1/1 symbol 1/1 date 564/587
# base: timeframe 1/1 symbol 1/1 date 565/587
# base: timeframe 1/1 symbol 1/1 date 566/587
# base: timeframe 1/1 symbol 1/1 date 567/587
# base: timeframe 1/1 symbol 1/1 date 568/587
# base: timeframe 1/1 symbol 1/1 date 569/587
# base: timeframe 1/1 symbol 1/1 date 570/587
# base: timeframe 1/1 symbol 1/1 date 571/587
# base: timeframe 1/1 symbol 1/1 date 572/587
# base: timeframe 1/1 symbol 1/1 date 573/587
# base: timeframe 1/1 symbol 1/1 date 574/587
# base: timeframe 1/1 symbol 1/1 date 575/587
# base: timeframe 1/1 symbol 1/1 date 576/587
# base: timeframe 1/1 symbol 1/1 date 577/587
# base: timeframe 1/1 symbol 1/1 date 578/587
# base: timeframe 1/1 symbol 1/1 date 579/587
# base: timeframe 1/1 symbol 1/1 date 580/587
# base: timeframe 1/1 symbol 1/1 date 581/587
# base: timeframe 1/1 symbol 1/1 date 582/587
# base: timeframe 1/1 symbol 1/1 date 583/587
# base: timeframe 1/1 symbol 1/1 date 584/587
# base: timeframe 1/1 symbol 1/1 date 585/587
# base: timeframe 1/1 symbol 1/1 date 586/587
# base: timeframe 1/1 symbol 1/1 date 587/587

# %% [markdown]
# ### Add signal

# %%
ohlcv_df_dict = add_signal(start_date, ohlcv_df_dict, interval_dict, config_params)
# Out:
# base add tma to ETH-PERP 2h

# %% [markdown]
# ### Back test

# %%
action_time_list = gen_action_time_list(config_params, ohlcv_df_dict)
max_open_timeframe = get_max_open_timeframe(config_params, interval_dict)

# %%
budget = 100

transaction_dict = {
    'symbol': [],
    'side': [],
    'amount': [],
    'open_time': [],
    'open_price': [],
    'close_time': [],
    'close_price': [],
    'notional': [],
    'profit': [],
    'profit_percent': []
}

position_dict = {}

if reinvest_profit_flag == True:
    budget_dict = {
        'time': [],
        'budget': []
    }
    
max_drawdown = 0

# %%
if reinvest_profit_flag == True:
    min_budget = budget

time_count = 0

for signal_time in action_time_list:
    action_time = signal_time + dt.timedelta(minutes=interval_dict[config_params['action_timeframe']])
    
    time_count += 1
    print(f"Time {action_time}: progress {time_count}/{len(action_time_list)}")

    '''
    Close positions
    '''
    for symbol in [x for x in position_dict.keys()]:
        print(f"  {symbol}")
        budget, max_drawdown, position_dict, transaction_dict = close_position(symbol, signal_time, max_drawdown, config_params, budget, reinvest_profit_flag, ohlcv_df_dict, position_dict, transaction_dict, interval_dict)

    '''
    Open positions
    '''
    max_position = int(1 / config_params['action_percent'])

    for symbol in [x for x in config_params['base']['symbol'] if x not in position_dict.keys()][:max_position]:
        print(f"  {symbol}")
        position_dict = open_position(symbol, signal_time, max_open_timeframe, config_params, budget, ohlcv_df_dict, position_dict, interval_dict)    
    
    '''
    Update budget
    '''
    if reinvest_profit_flag == True:
        budget_dict['time'].append(signal_time)
        budget_dict['budget'].append(budget)

        if budget < min_budget:
            min_budget = budget

    if budget <= 0:
        print(f"Out of money at {action_time}")
        break
        
'''
Clear final position
'''
opened_symbol = list(position_dict.keys())

for symbol in opened_symbol:
    print(f" Clear {symbol} position")
    
    side = position_dict[symbol]['side']
    ohlcv_df = ohlcv_df_dict['base'][config_params['action_timeframe']][symbol]
    current_ohlcv_df = ohlcv_df[ohlcv_df['time'] == signal_time].reset_index(drop=True)
    close_price = current_ohlcv_df.loc[0, 'close']
    
    budget, position_dict, transaction_dict = update_close_position(symbol, side, close_price, signal_time, config_params, budget, reinvest_profit_flag, position_dict, transaction_dict, interval_dict)
# Out:
# Time 2021-01-01 03:00:00: progress 1/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 05:00:00: progress 2/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 07:00:00: progress 3/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 09:00:00: progress 4/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 11:00:00: progress 5/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 13:00:00: progress 6/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 15:00:00: progress 7/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 17:00:00: progress 8/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 19:00:00: progress 9/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 21:00:00: progress 10/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-01 23:00:00: progress 11/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: no_action
#      No action
# Time 2021-01-02 01:00:00: progress 12/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      base ETH-PERP check_signal_side_change tma 2h: buy
#      buy: 0.1370614035087719
#      price: 729.6
#      tp: inf
#      sl: 0
# Time 2021-01-02 03:00:00: progress 13/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 05:00:00: progress 14/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 07:00:00: progress 15/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 09:00:00: progress 16/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 11:00:00: progress 17/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 13:00:00: progress 18/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 15:00:00: progress 19/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 17:00:00: progress 20/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 19:00:00: progress 21/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2021-01-02 21:00:00: progress 22/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Closed by signal at 773.76
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: sell
#      sell: 0.13687499319794522
#      price: 773.76
#      tp: 0
#      sl: inf
# Time 2021-01-02 23:00:00: progress 23/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 01:00:00: progress 24/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 03:00:00: progress 25/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 05:00:00: progress 26/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 07:00:00: progress 27/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 09:00:00: progress 28/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 11:00:00: progress 29/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 13:00:00: progress 30/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 15:00:00: progress 31/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 17:00:00: progress 32/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 19:00:00: progress 33/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 21:00:00: progress 34/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-03 23:00:00: progress 35/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 01:00:00: progress 36/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 03:00:00: progress 37/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 05:00:00: progress 38/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 07:00:00: progress 39/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 09:00:00: progress 40/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 11:00:00: progress 41/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 13:00:00: progress 42/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 15:00:00: progress 43/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 17:00:00: progress 44/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 19:00:00: progress 45/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 21:00:00: progress 46/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-04 23:00:00: progress 47/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 01:00:00: progress 48/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 03:00:00: progress 49/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 05:00:00: progress 50/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 07:00:00: progress 51/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 09:00:00: progress 52/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 11:00:00: progress 53/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 13:00:00: progress 54/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 15:00:00: progress 55/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 17:00:00: progress 56/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 19:00:00: progress 57/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 21:00:00: progress 58/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-05 23:00:00: progress 59/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 01:00:00: progress 60/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 03:00:00: progress 61/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 05:00:00: progress 62/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 07:00:00: progress 63/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 09:00:00: progress 64/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 11:00:00: progress 65/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 13:00:00: progress 66/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 15:00:00: progress 67/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 17:00:00: progress 68/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 19:00:00: progress 69/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 21:00:00: progress 70/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-06 23:00:00: progress 71/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-07 01:00:00: progress 72/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2021-01-07
5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-20 13:00:00: progress 4986/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-20 15:00:00: progress 4987/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-20 17:00:00: progress 4988/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-20 19:00:00: progress 4989/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-20 21:00:00: progress 4990/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-20 23:00:00: progress 4991/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 01:00:00: progress 4992/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 03:00:00: progress 4993/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 05:00:00: progress 4994/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 07:00:00: progress 4995/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 09:00:00: progress 4996/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 11:00:00: progress 4997/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 13:00:00: progress 4998/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 15:00:00: progress 4999/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 17:00:00: progress 5000/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 19:00:00: progress 5001/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 21:00:00: progress 5002/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-21 23:00:00: progress 5003/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 01:00:00: progress 5004/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 03:00:00: progress 5005/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 05:00:00: progress 5006/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 07:00:00: progress 5007/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 09:00:00: progress 5008/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 11:00:00: progress 5009/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 13:00:00: progress 5010/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 15:00:00: progress 5011/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 17:00:00: progress 5012/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 19:00:00: progress 5013/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 21:00:00: progress 5014/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-22 23:00:00: progress 5015/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-23 01:00:00: progress 5016/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-23 03:00:00: progress 5017/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-23 05:00:00: progress 5018/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-23 07:00:00: progress 5019/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-23 09:00:00: progress 5020/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-23 11:00:00: progress 5021/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-23 13:00:00: progress 5022/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Closed by signal at 2658.3
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      base ETH-PERP check_signal_side_change tma 2h: sell
#      sell: 0.0007622946824368133
#      price: 2658.3
#      tp: 0
#      sl: inf
# Time 2022-02-23 15:00:00: progress 5023/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2022-02-23 17:00:00: progress 5024/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2022-02-23 19:00:00: progress 5025/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2022-02-23 21:00:00: progress 5026/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2022-02-23 23:00:00: progress 5027/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2022-02-24 01:00:00: progress 5028/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: sell
#      Not close
# Time 2022-02-24 03:00:00: progress 5029/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Closed by signal at 2634.1
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      base ETH-PERP check_signal_side_change tma 2h: buy
#      buy: 0.0007752292729101486
#      price: 2634.1
#      tp: inf
#      sl: 0
# Time 2022-02-24 05:00:00: progress 5030/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 07:00:00: progress 5031/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 09:00:00: progress 5032/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 11:00:00: progress 5033/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 13:00:00: progress 5034/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 15:00:00: progress 5035/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 17:00:00: progress 5036/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 19:00:00: progress 5037/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 21:00:00: progress 5038/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-24 23:00:00: progress 5039/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
# Time 2022-02-25 01:00:00: progress 5040/5040
#   ETH-PERP
#      base ETH-PERP check_signal_price tma 2h: buy
#      Not close
#  Clear ETH-PERP position

# %%
end_ts = time.time()
time_process = end_ts - start_ts
print(f"Time process: {round(time_process / 60, 2)} minutes")
# Out:
# Time process: 1.75 minutes

# %% [markdown]
# ### Result

# %%
transaction_df = pd.DataFrame(transaction_dict)
transaction_df.to_csv(f'output/{project_name}.csv', index=False)
transaction_df
# Out:
#        symbol  side    amount           open_time  open_price  \
# 0    ETH-PERP   buy  0.137061 2021-01-02 01:00:00      729.60
# 1    ETH-PERP  sell  0.136875 2021-01-02 21:00:00      773.76
# 2    ETH-PERP   buy  0.037806 2021-01-11 09:00:00     1211.50
# 3    ETH-PERP  sell  0.037752 2021-01-14 05:00:00     1128.80
# 4    ETH-PERP   buy  0.039887 2021-01-14 11:00:00     1097.00
# ..        ...   ...       ...                 ...         ...
# 262  ETH-PERP   buy  0.000751 2022-02-11 03:00:00     3123.10
# 263  ETH-PERP  sell  0.000750 2022-02-15 09:00:00     3023.10
# 264  ETH-PERP   buy  0.000763 2022-02-17 21:00:00     2994.50
# 265  ETH-PERP  sell  0.000762 2022-02-23 13:00:00     2658.30
# 266  ETH-PERP   buy  0.000775 2022-02-24 03:00:00     2634.10
#
#              close_time  close_price    notional     profit  profit_percent
# 0   2021-01-02 21:00:00       773.76  100.000000   5.908395        5.904262
# 1   2021-01-11 09:00:00      1211.50  105.908395 -60.105872      -56.792453
# 2   2021-01-14 05:00:00      1128.80   45.802523  -3.188529       -6.956600
# 3   2021-01-14 11:00:00      1097.00   42.613994   1.141681        2.681000
# 4   2021-01-14 13:00:00      1111.10   43.755675   0.500750        1.143623
# ..                  ...          ...         ...        ...             ...
# 262 2022-02-15 09:00:00      3023.10    2.346154  -0.078355       -3.337369
# 263 2022-02-17 21:00:00      2994.50    2.267800   0.018295        0.807276
# 264 2022-02-23 13:00:00      2658.30    2.286094  -0.259686      -11.351445
# 265 2022-02-24 03:00:00      2634.10    2.026408   0.015623        0.771534
# 266 2022-02-25 01:00:00      2435.80    2.042031  -0.156479       -7.657558
#
# [267 rows x 10 columns]

# %%
if reinvest_profit_flag == True:
    print(f"Final budget: {round(budget, 2)}")
else:
    print("Not reinvest profit")
# Out:
# Final budget: 1.89

# %%
if reinvest_profit_flag == True:
    return_percent = (budget_dict['budget'][-1] - budget_dict['budget'][0]) / budget_dict['budget'][0] * 100
    print(f"Return: {round(return_percent, 2)}%")
else:
    print("Not reinvest profit")
# Out:
# Return: -97.96%

# %%
if reinvest_profit_flag == True:
    fig, ax = plt.subplots(figsize=(30, 8))
    ax.plot(budget_dict['time'], budget_dict['budget'])
else:
    print("Not reinvest profit")

# %%
if reinvest_profit_flag == True:
    print(f"Max drawdown: {round(max_drawdown * 100, 2)}%")
# Out:
# Max drawdown: 88.69%

# %%
win_rate = len(transaction_df[transaction_df['profit'] > 0]) / len(transaction_df)
print(f"Win rate: {round(win_rate * 100, 2)}%")
# Out:
# Win rate: 71.16%

# %%
for symbol in transaction_df['symbol'].unique():
    symbol_df = transaction_df[transaction_df['symbol'] == symbol]
    win_rate = len(symbol_df[symbol_df['profit'] > 0]) / len(symbol_df)
    print(f"{symbol} win rate: {round(win_rate * 100, 2)}%")
# Out:
# ETH-PERP win rate: 71.16%

# %%
print(f"Distribution")
print(pd.DataFrame(transaction_df['profit_percent'].describe()))
# Out:
# Distribution
#        profit_percent
# count      267.000000
# mean        -1.067081
# std          7.525437
# min        -64.739527
# 25%         -0.580999
# 50%          0.871333
# 75%          1.908115
# max          6.687191

# %%
for symbol in transaction_df['symbol'].unique():
    temp_return = transaction_df[transaction_df['symbol'] == symbol]['profit_percent']
    
    print(f"Distribution {symbol}:")
    print(pd.DataFrame(temp_return.describe()))
    print("\n")
# Out:
# Distribution ETH-PERP:
#        profit_percent
# count      267.000000
# mean        -1.067081
# std          7.525437
# min        -64.739527
# 25%         -0.580999
# 50%          0.871333
# 75%          1.908115
# max          6.687191

# %%
fig, ax = plt.subplots(figsize=(30, 8))
_ = ax.hist(transaction_df['profit_percent'], bins=10)
